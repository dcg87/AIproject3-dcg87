# %% [markdown]
# # Algorithm

# %% [markdown]
# # Features

# %% [markdown]
# Each pixel is a feature.

# %%
from naivebayes import read_label_data
from perceptron import *
import random
import time
import numpy as np
import matplotlib.pyplot as plt

# %%
#load data
train_image_data = read_image_data("./facedata/facedatatrain",451)
test_image_data = read_image_data("./facedata/facedatatest",150)      
train_label_data = read_label_data("./facedata/facedatatrainlabels")
test_label_data = read_label_data("./facedata/facedatatestlabels")

# %%
X_train = np.array(make_feature_vectors(train_image_data,train_label_data))
X_test = np.array(make_feature_vectors(test_image_data,test_label_data))
W_train = np.array([[0 for pixel in line] for line in X_train])
W_test = np.array([[0 for pixel in line] for line in X_test])
D_train = np.array([int(data) for data in train_label_data])
D_test = np.array([int(data) for data in test_label_data])
Y_train = np.zeros([len(X_train)])
Y_test = np.zeros([len(X_test)])

n_iter = [2,4,8,16,32,64,128,256,512,1024] #10 different allowed iterations
size = [45*n for n in range(1,11)] #10 different sizes of training set


avg_time = list()
avg_acc = list()


for s in size: #10% training set, 20% training set, ...
    k= round((s / len(X_train)) * 100.0)
    for it in n_iter: #2 iterations, 4 iterations, 8 iterations, 16 iterations, ... 
        print(f"{k}% training data, {it} trials) ") # 
        #sample x% of training set
        sample = random.sample([(x,w,d,y) for (x,w,d,y) in zip(X_train,W_train,D_train,Y_train)],s)
        #train the perceptron
        perceptron([p[0] for p in sample],
                          [p[1] for p in sample],
                          [p[2] for p in sample],
                          [p[3] for p in sample],
                          it)
        #test the perceptron
        acc, times = perceptron(X_test,W_test,D_test,Y_test,it)
        avg_acc.append(acc)
        avg_time.append(acc)
        
# report average accuracy for [2,4,8,16,...] iterations;  report standard deviation 
print(f"accuracy(mean,{n_iter} iterations): " + str(round(np.average(np.array(avg_acc)),2) )) 
print("std: " + str(round(np.std(np.array(avg_acc)),2)))
# Out:
# 10% training data, 2 trials)
# 10% training data, 4 trials)
# 10% training data, 8 trials)
# 10% training data, 16 trials)
# 10% training data, 32 trials)
# 10% training data, 64 trials)
# 10% training data, 128 trials)
# 10% training data, 256 trials)
# 10% training data, 512 trials)
# 10% training data, 1024 trials)
# 20% training data, 2 trials)
# 20% training data, 4 trials)
# 20% training data, 8 trials)
# 20% training data, 16 trials)
# 20% training data, 32 trials)
# 20% training data, 64 trials)
# 20% training data, 128 trials)
# 20% training data, 256 trials)
# 20% training data, 512 trials)
# 20% training data, 1024 trials)
# 30% training data, 2 trials)
# 30% training data, 4 trials)
# 30% training data, 8 trials)
# 30% training data, 16 trials)
# 30% training data, 32 trials)
# 30% training data, 64 trials)
# 30% training data, 128 trials)
# 30% training data, 256 trials)
# 30% training data, 512 trials)
# 30% training data, 1024 trials)
# 40% training data, 2 trials)
# ...

# %% [markdown]
# # Results

# %% [markdown]
# Average accuracy is 88 percent, with a standard deviation of 0.13. The perceptron appears to be insensitive to changes in the size of the training data set, but accuracy is directly proprtional to the number of iterations the perceptron is allowed. No more than 250 iterations are required to achieve 90% accuracy; no more than 550 iterations for 97% accuracy. As is evident, diminishing returns render iteration past 550 unprofitable. Interestingly, for training data > 10%, accuracy dips dramatically between [20,150] iterations, and then rises dramatically from [150,220].

# %%
fig =  plt.figure(figsize=(10,10))
ax = plt.subplot()

ax.plot(n_iter,avg_acc[0:10])

fig.suptitle('n Iterations vs. Accuracy (10% training data)')
ax.set_xlabel('n Iterations')
ax.set_ylabel('Accuracy')

plt.show()

# %%
fig =  plt.figure(figsize=(10,10))
ax = plt.subplot()

ax.plot(n_iter,avg_acc[10:20])

fig.suptitle('n Iterations vs. Accuracy (20% training data)')
ax.set_xlabel('n Iterations')
ax.set_ylabel('Accuracy')

plt.show()

# %%
fig =  plt.figure(figsize=(10,10))
ax = plt.subplot()

ax.plot(n_iter,avg_acc[20:30])

fig.suptitle('n Iterations vs. Accuracy (30% training data)')
ax.set_xlabel('n Iterations')
ax.set_ylabel('Accuracy')

plt.show()

# %%
fig =  plt.figure(figsize=(10,10))
ax = plt.subplot()

ax.plot(n_iter,avg_acc[30:40])

fig.suptitle('n Iterations vs. Accuracy (40% training data)')
ax.set_xlabel('n Iterations')
ax.set_ylabel('Accuracy')

plt.show()

# %%
fig =  plt.figure(figsize=(10,10))
ax = plt.subplot()

ax.plot(n_iter,avg_acc[40:50])

fig.suptitle('n Iterations vs. Accuracy (50% training data)')
ax.set_xlabel('n Iterations')
ax.set_ylabel('Accuracy')

plt.show()

# %%
fig =  plt.figure(figsize=(10,10))
ax = plt.subplot()

ax.plot(n_iter,avg_acc[50:60])

fig.suptitle('n Iterations vs. Accuracy (60% training data)')
ax.set_xlabel('n Iterations')
ax.set_ylabel('Accuracy')

plt.show()

# %%
fig =  plt.figure(figsize=(10,10))
ax = plt.subplot()

ax.plot(n_iter,avg_acc[60:70])

fig.suptitle('n Iterations vs. Accuracy (70% training data)')
ax.set_xlabel('n Iterations')
ax.set_ylabel('Accuracy')

plt.show()

# %%
fig =  plt.figure(figsize=(10,10))
ax = plt.subplot()

ax.plot(n_iter,avg_acc[70:80])
fig.suptitle('n Iterations vs. Accuracy (80% training data)')
ax.set_xlabel('n Iterations')
ax.set_ylabel('Accuracy')

plt.show()

# %%
fig =  plt.figure(figsize=(10,10))
ax = plt.subplot()

ax.plot(n_iter,avg_acc[80:90])

fig.suptitle('n Iterations vs. Accuracy (90% training data)')
ax.set_xlabel('n Iterations')
ax.set_ylabel('Accuracy')

plt.show()

# %%
fig =  plt.figure(figsize=(10,10))
ax = plt.subplot()

ax.plot(n_iter,avg_acc[90:100])

fig.suptitle('n Iterations vs. Accuracy (100% training data)')
ax.set_xlabel('n Iterations')
ax.set_ylabel('Accuracy')

plt.show()
